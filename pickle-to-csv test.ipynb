# %%
# Zakljucak: Moze se, samo csv vraca brojeve

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn import neighbors

pd.set_option('display.max_columns', None)

df = pd.read_pickle('./stanovi/data.pkl')

# %%
df.to_csv('./stanovi/new_data.csv')

# %%
df1 = pd.read_csv('./stanovi/new_data.csv')

# %%
# df.equals(df1.drop(['Unnamed: 0'], axis=1))
df.equals(df)
# Out:
# True

# %%
df1['Unnamed: 0']
# Out:
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
#        ...
# 1654    435
# 1655    436
# 1656    437
# 1657    438
# 1658    439
# Name: Unnamed: 0, Length: 1659, dtype: int64

# %%
df.head()
# Out:
#    index propertyCode                                          thumbnail  \
# 0      0     87688139  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 1      1     89127122  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 2      2     89115559  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3      3     89102591  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 4      4     89123676  https://img3.idealista.com/blur/WEB_LISTING/0/...
#
#   externalReference  numPhotos floor     price propertyType operation  size  \
# 0          60133710          6     3  172000.0         flat      sale  67.0
# 1          J-SEBRAV         10     2  130000.0         flat      sale  32.0
# 2            ARN159         28     1  149000.0         flat      sale  45.0
# 3      D-santpau230         23     5  220000.0         flat      sale  54.0
# 4        Ref.405-11          7    bj  103000.0         flat      sale  67.0
#
# ...

# %%
d1,d2 = df.shape
for i in range(d1):
    for j in range(d2):
        print(i,j)
# Out:
#   File "<ipython-input-35-2ab4d8c63e3d>", line 6
#     for i,j in zip(range(d1), range(d2)):
#                                          ^
# IndentationError: expected an indented block

# %%
a = df.iloc[0,23]
b = df1.iloc[0,23]
b
# Out:
# 1154

# %%
from itertools import product
#dff=df.fillna(0)
#dff1=df1.fillna(0)
for i,j in product(range(d1), range(d2)):
    if str(df.iloc[i,j])!=str(df1.iloc[i,j]):
        print(i,j,df.iloc[i,j],df1.iloc[i,j])
# Out:
# 2 19 41.4305817 41.430581700000005
# 2 20 2.1774487 2.1774487000000002
# 6 20 2.2074923 2.2074922999999997
# 8 19 41.4195009 41.419500899999996
# 9 19 41.3603731 41.360373100000004
# 10 19 41.4147797 41.414779700000004
# 11 19 41.4168208 41.416820799999996
# 12 20 2.1335494 2.1335493999999997
# 15 19 41.4018434 41.401843400000004
# 18 20 2.1834941 2.1834941000000003
# 19 19 41.4051738 41.40517379999999
# 20 20 2.1738233 2.1738232999999996
# 23 20 2.1841941 2.1841941000000005
# 24 19 41.3714866 41.371486600000004
# 25 19 41.3697267 41.36972670000001
# 26 19 41.3720918 41.37209179999999
# 26 20 2.1440225 2.1440224999999997
# 27 19 41.3645962 41.36459620000001
# 27 20 2.1256261 2.1256261000000003
# 28 20 2.1757011 2.1757011000000004
# 29 20 2.1727233 2.1727232999999995
# 30 19 41.4052179 41.405217900000004
# 31 19 41.4218319 41.421831899999994
# 31 20 2.2056898 2.2056897999999996
# 32 19 41.3663232 41.366323200000004
# 33 20 2.1771983 2.1771982999999997
# ...

# %%
df.head()
# Out:
#    index propertyCode                                          thumbnail  \
# 0      0     87688139  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 1      1     89127122  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 2      2     89115559  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3      3     89102591  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 4      4     89123676  https://img3.idealista.com/blur/WEB_LISTING/0/...
#
#   externalReference  numPhotos floor     price propertyType operation  size  \
# 0          60133710          6     3  172000.0         flat      sale  67.0
# 1          J-SEBRAV         10     2  130000.0         flat      sale  32.0
# 2            ARN159         28     1  149000.0         flat      sale  45.0
# 3      D-santpau230         23     5  220000.0         flat      sale  54.0
# 4        Ref.405-11          7    bj  103000.0         flat      sale  67.0
#
# ...

# %%
df1.head()
# Out:
#    index  propertyCode                                          thumbnail  \
# 0      0      87688139  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 1      1      89127122  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 2      2      89115559  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3      3      89102591  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 4      4      89123676  https://img3.idealista.com/blur/WEB_LISTING/0/...
#
#   externalReference  numPhotos floor     price propertyType operation  size  \
# 0          60133710          6     3  172000.0         flat      sale  67.0
# 1          J-SEBRAV         10     2  130000.0         flat      sale  32.0
# 2            ARN159         28     1  149000.0         flat      sale  45.0
# 3      D-santpau230         23     5  220000.0         flat      sale  54.0
# 4        Ref.405-11          7    bj  103000.0         flat      sale  67.0
#
# ...

# %%
df.head()
# Out:
#    index propertyCode                                          thumbnail  \
# 0      0     87688139  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 1      1     89127122  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 2      2     89115559  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3      3     89102591  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 4      4     89123676  https://img3.idealista.com/blur/WEB_LISTING/0/...
#
#   externalReference  numPhotos floor     price propertyType operation  size  \
# 0          60133710          6     3  172000.0         flat      sale  67.0
# 1          J-SEBRAV         10     2  130000.0         flat      sale  32.0
# 2            ARN159         28     1  149000.0         flat      sale  45.0
# 3      D-santpau230         23     5  220000.0         flat      sale  54.0
# 4        Ref.405-11          7    bj  103000.0         flat      sale  67.0
#
# ...
